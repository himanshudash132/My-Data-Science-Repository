# %%
import pandas as pd
df = pd.read_csv("/Users/shridharmankar/age2.csv")
df.head(6)
# Out:
#    Age  Degrees  Income
# 0   50        5    5000
# 1   60        3    4500
# 2   10        1    7000
# 3   20        2    6000
# 4   40        7    3500
# 5   80        9    2000

# %%
import matplotlib.pyplot as plt
plt.scatter(df['Age'],df['Income'])
plt.xlabel('Age')
plt.ylabel('Income')
plt.show()

# %%
plt.scatter(df['Degrees'],df['Income'])
plt.xlabel('Degrees')
plt.ylabel('Income')
plt.show()

# %%
x = df[['Age', 'Degrees']]
y = df['Income']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x,y,test_size=0.3,random_state=0)
X_train
# Out:
#    Age  Degrees
# 1   60        3
# 3   20        2
# 0   50        5
# 4   40        7

# %%
X_test
# Out:
#    Age  Degrees
# 5   80        9
# 2   10        1

# %%
from sklearn.linear_model import LinearRegression
clf = LinearRegression()

# %%
clf.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
clf.predict(X_test)
# Out:
# array([2314.81481481, 6555.55555556])

# %%
clf.score(X_test, y_test)
# Out:
# 0.9762688614540466

# %%
clf.coef_
# Out:
# array([ -20.37037037, -351.85185185])

# %%
clf.intercept_
# Out:
# 7111.1111111111095

# %%
y_pred = clf.predict(x)
y_pred
# Out:
# array([4333.33333333, 4833.33333333, 6555.55555556, 6000.        ,
#        3833.33333333, 2314.81481481])

# %%
from sklearn.datasets import make_regression
x,y = make_regression(n_features=5, noise=5, n_samples=10000)

# %%
x
# Out:
# array([[ 1.58546503,  0.45336884,  0.34497576,  0.56771634, -1.57602456],
#        [ 1.24128156, -0.91858229,  0.50409325, -2.30326679, -0.29956392],
#        [-1.99273195,  0.82952245,  0.4201318 , -0.5975859 , -0.52736814],
#        ...,
#        [-1.74092246, -0.23615396, -1.69401609,  1.7120428 , -0.93355368],
#        [-1.87679958,  0.27352938, -0.17556727,  0.98737942,  1.96756153],
#        [ 0.35028555, -0.46842567, -0.92640133, -2.67633282,  0.21845579]])

# %%
y
# Out:
# array([ 201.81345305,  -85.09274338, -116.86878913, ..., -142.87144185,
#         -74.41509717, -203.40271778])

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state=0)

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
regressor.predict(X_test)
# Out:
# array([-463.68749503, -152.42628229,  -23.71215455, ...,  -16.18741973,
#          -0.80582008, -247.13670503])

# %%
regressor.score(X_test, y_test)
# Out:
# 0.9986585496357336

# %%
regressor.coef_
# Out:
# array([84.25868447, 81.32447353, 43.2236268 , 58.57938473,  5.70908651])

# %%
regressor.intercept_
# Out:
# -0.03589609002275207
